# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
matplotlib.rcParams["figure.figsize"]= (20,10)

# %%
df1= pd.read_csv(".\\dataset\\air_data.csv")
df1.head()
# Out:
# C:\Users\MBHS\AppData\Local\Temp\ipykernel_16508\2341055628.py:1: DtypeWarning: Columns (0,2,4,5,6,11,18,19,26,28,29,30,31,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1= pd.read_csv(".\\dataset\\air_data.csv")
#                                      organization_id  \
# 0  The GLOBE ID assigned to the school or organiz...
# 1                                           20826740
# 2                                           20826740
# 3                                           20826740
# 4                                           20826740
#
#                                             org_name  \
# 0  The name of the reporting school or other inst...
# 1                    Alpena Elementary/Middle School
# 2                    Alpena Elementary/Middle School
# 3                    Alpena Elementary/Middle School
# 4                    Alpena Elementary/Middle School
#
#                              site_id  \
# ...

# %%
df1.shape
# Out:
# (45995, 37)

# %%
df1.isnull().sum()
# Out:
# organization_id                                                 0
#  org_name                                                       0
#  site_id                                                        0
#  site_name                                                      0
#  latitude                                                       0
#  longitude                                                      0
#  elevation                                                      0
#  measured_on                                                    0
#  air temps:userid                                             292
# air temps:measured at                                         292
# air temps:solar measured at                                   292
# air temps:current temp (deg C)                                292
# air temps:comments                                           4227
# air temps:globe teams                                        3167
# ...

# %%
print(df1.columns)
# Out:
# Index(['organization_id', ' org_name', ' site_id', ' site_name', ' latitude',
#        ' longitude', ' elevation', ' measured_on', ' air temps:userid',
#        'air temps:measured at', 'air temps:solar measured at',
#        'air temps:current temp (deg C)', 'air temps:comments',
#        'air temps:globe teams', 'humidities:userid', 'humidities:measured at',
#        'humidities:solar measured at', 'humidities:solar noon at',
#        'humidities:relative humidity (%)', 'humidities:dewpoint',
#        'humidities:comments', 'humidities:globe teams',
#        'surface temperatures:userid', 'surface temperatures:measured at',
#        'surface temperatures:solar measured at',
#        'surface temperatures:solar noon at',
#        'surface temperatures:average surface temperature (deg C)',
#        'surface temperatures:surface condition',
#        'surface temperatures:average snow depth mm',
#        'surface temperatures:snow depth flag',
# ...

# %%
df2=df1.drop(['organization_id',' site_id',' site_name',' elevation',' measured_on',' air temps:userid','air temps:measured at','air temps:solar measured at','air temps:comments','air temps:globe teams','humidities:userid',
        'humidities:measured at','humidities:solar measured at','humidities:solar noon at','humidities:dewpoint',
       'humidities:comments', 'humidities:globe teams',
       'surface temperatures:userid', 'surface temperatures:measured at',
       'surface temperatures:solar measured at',
       'surface temperatures:solar noon at','surface temperatures:average snow depth mm',
       'surface temperatures:snow depth flag',
       'surface temperatures:number of samples taken','surface temperatures:comments',
       'surface temperatures:surface cover type','surface temperatures:globe teams','surface temperatures:homogeneous site short length (m)',
       'surface temperatures:homogeneous site long length (m)',
       'surface temperatures:site area m squared'],axis='columns')
df2.head()
# Out:
#                                             org_name  \
# 0  The name of the reporting school or other inst...
# 1                    Alpena Elementary/Middle School
# 2                    Alpena Elementary/Middle School
# 3                    Alpena Elementary/Middle School
# 4                    Alpena Elementary/Middle School
#
#                                             latitude  \
# 0  The latitude of the site where data were obser...
# 1                                            36.2895
# 2                                           36.04913
# 3                                           36.04913
# 4                                           36.04913
#
#                                            longitude  \
# 0  The longitude of the site where date were obse...
# 1                                         -93.297337
# 2                                         -93.071055
# 3                                         -93.071055
# ...

# %%
df2.to_csv('.\\dataset\\air_data_clean_1.csv')

# %%
df3=df2.drop([' org_name',' latitude',' longitude'],axis='columns')
df3.head()
# Out:
#        air temps:current temp (deg C) humidities:relative humidity (%)  \
# 0  Air temperature in degrees Celsius        Percent relative humidity
# 1                                23.9                              NaN
# 2                                27.3                              NaN
# 3                                28.3                              NaN
# 4                                25.8                              NaN
#
#   surface temperatures:average surface temperature (deg C)  \
# 0            Average surface temperature (degrees C)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#              surface temperatures:surface condition
# 0  Surface condition (wet, dry, frozen, snow cover)
# 1                                               NaN
# 2                                               NaN
# ...

# %%
df3.to_csv('.\\dataset\\air_data_clean_2.csv')
